# %% [markdown]
# <a href="https://colab.research.google.com/github/nxthxnael/Machine-Learning-Essentials/blob/master/Practical%20Session%201/classification-algorithms.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Step 1**
#
# I will import the Iris dataset from the scikit learn library.
#
# > *It contains features for different iris flower species, which the model will learn to categorize.*
#
# - I will run `sklearn.datasets import load_iris`
# - I will also import pandas, load the dataset and create a dataframe
#
# Then I will display the first few rows of the dataset.

# %%
from sklearn.datasets import load_iris
import pandas as pd

# loading the dataset
iris = load_iris()

# %%
# creating a dataframe

iris_df = pd.DataFrame(iris.data, columns=iris.feature_names)
iris_df['target'] = iris.target

# I'm adding the target column to include the additional information
# (numerical values representing the species)

print(iris_df.head())
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
